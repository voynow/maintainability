# %%
# %reload_ext autoreload
# %autoreload 2

from maintainability.api.src import routes_helper

# %%
files_metrics = routes_helper.join_files_metrics("voynow99@gmail.com", "maintainability")
weighted_metrics = routes_helper.calculate_weighted_metrics(files_metrics)
plot_json = routes_helper.generate_plotly_figs(weighted_metrics)
enriched_plot = routes_helper.enrich_description(plot_json)
# Out:
# 2023-11-03 08:36:17,515:INFO - HTTP Request: GET https://mgydwipshkixnewazzqb.supabase.co/rest/v1/files?select=%2A&user_email=eq.voynow99%40gmail.com&project_name=eq.maintainability "HTTP/1.1 200 OK"
# ...

# %%
enriched_plot
# Out:
# [{'data': [{'line': {'color': '#1F77B4', 'width': 3},
#     'marker': {'color': '#1F77B4', 'size': 10},
#     'mode': 'lines+markers',
#     'name': 'Intuitive design',
#     'x': [datetime.date(2023, 10, 22),
#      datetime.date(2023, 10, 23),
#      datetime.date(2023, 10, 24),
#      datetime.date(2023, 10, 25),
#      datetime.date(2023, 10, 26),
#      datetime.date(2023, 10, 27),
#      datetime.date(2023, 10, 28),
#      datetime.date(2023, 10, 29),
#      datetime.date(2023, 10, 30),
#      datetime.date(2023, 10, 31),
#      datetime.date(2023, 11, 1),
#      datetime.date(2023, 11, 2)],
#     'y': [7.5341586428243925,
#      7.627306273062731,
#      7.379989356040447,
#      7.532877882152007,
#      7.659192825112107,
#      7.7026813880126195,
#      7.706293706293707,
#      7.480897009966777,
#      7.750104297037963,
#      7.769102990033223,
#      7.357377049180327,
#      7.283879781420763],
#     'type': 'scatter'}],
# ...
